# %% [markdown]
# ## In this notebook, I want to take our survey flux densities (at 1.4 or 3 GHz) and errors, and:
#
# * Compute 6 GHz luminosities and their corresponding errors by propagating through the measured errors on their flux density from imfit (both for the case of $\alpha=0.0$ and $\alpha=-0.7$
#
#
# * Save the 6 GHz flux density and corrseponding error that luminosity corresponds to. These may be useful for later computing variability amplitudes (Barvainis et al. 2005)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import richardsplot
from astropy.cosmology import FlatLambdaCDM

# %%
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

def radluminosity(nu1, nu2, S_nu2, alpha, z):
    #calculate luminosity at nu1 based on data at nu2
    #input flux density units are µJy
    DL = 3.086e24*cosmo.luminosity_distance(z).value
    L = ((4*np.pi*DL**2*(S_nu2*1e-23*1e-6)) / ((1+z)**(1+alpha))) * (nu1/nu2)**alpha * 1e-7
    return np.log10(L)

def LtoS(nu1, nu2, L_nu2, alpha, z):
    #Compute flux at nu2 given log L at nu1
    DL = 3.086e24*cosmo.luminosity_distance(z).value
    L = 10**L_nu2
    S = L * (((1+z)**(1+alpha))/(4*np.pi*DL**2)) * 1e36 * (nu2/nu1)**alpha
    return S
    
def isNAN(arr):
    #this isnan works for strings too; np.isnan(a) only works if all elements
    #is arr are floats
    return arr!=arr

# %%
df = pd.read_csv("all_var_figs.csv")
df
# Out:
#                   Name      z  S1p4_FIRST  S1p4_err  L6_FIRST  \
# 0   075403.60+481428.0  0.276        7910       160     23.80
# 1   083658.90+442602.2  0.254        9150       120     23.78
# 2   091702.11+212337.5  0.202        4190       130     23.23
# 3   094215.12+090015.8  0.213        1690       130     22.88
# 4   094603.94+013923.6  0.220        7330       150     23.55
# ..                 ...    ...         ...       ...       ...
# 65  145824.46+363119.5  0.246         495         0     22.49
# 66  084313.41+535718.8  0.218         516       150     22.39
# 67  123532.83+410445.1  0.212         510         0     22.35
# 68  161723.67+085414.7  0.206         450         0     22.28
# 69  142522.37+080327.1  0.230         366         0     21.81
#
#     L6_FIRST_alpha0  DATE_FIRST  S3_VLASS  S3_quaderr  L6_VLASS  ...  \
# 0             24.17  1997-04-10    4070.0       820.0     23.74  ...
# 1             24.15  1997-02-28    3940.0       805.0     23.65  ...
# 2             23.61  1998-09-15    4190.0       850.0     23.46  ...
# 3             23.27  2000-01-15    1300.0       279.0     23.00  ...
# 4             23.93  1998-07-24    3810.0       773.0     23.50  ...
# ..              ...         ...       ...         ...       ...  ...
# 65            22.86  1994-07-17       NaN         NaN     22.67  ...
# 66            22.77  1997-05-07       NaN         NaN     22.45  ...
# 67            22.74  1994-09-02       NaN         NaN     22.50  ...
# 68            22.66  2000-01-15       NaN         NaN     22.59  ...
# 69            22.19  2000-01-15       NaN         NaN     22.04  ...
#
#     DATE_VLASS  S(6)_p    pmp   DATE_VLAC S6_Aconfig  S6_Aconfig_err  \
# 0   2019-05-10  2631.0   84.8   2011-1-15        NaN             NaN
# 1   2019-05-24  2596.0   79.0   2011-1-15        NaN             NaN
# 2   2019-04-22  4790.0  144.4   2011-1-15        NaN             NaN
# 3   2017-10-02  1162.0   38.4   2011-1-15        NaN             NaN
# 4   2018-01-02  2471.0   76.1   2011-1-15        NaN             NaN
# ..         ...     ...    ...         ...        ...             ...
# 65  2017-11-10   167.0    9.4  2010-12-25      207.0       31.000000
# 66  2017-09-26   410.0   14.7  2010-12-26      349.0       31.000000
# 67  2019-04-15   266.0   16.1  2010-12-27      554.0       67.000000
# 68  2019-03-18   381.0   15.2  2010-12-28      386.7       18.164801
# 69  2019-05-08   138.0    6.5  2010-12-29      220.0       15.000000
#
#      DATE_VLAA CLASS S3_VLASS_final  S3_quaderr_final
# 0          NaN    RI         4395.6        952.860785
# 1          NaN    RI         4255.2        933.669863
# 2          NaN    RI         4525.2        986.802708
# 3          NaN    RI         1495.0        342.416242
# 4          NaN    RI         4381.5        955.560764
# ..         ...   ...            ...               ...
# 65  2019-09-20    RQ            NaN               NaN
# 66  2019-08-13    RQ            NaN               NaN
# 67  2019-08-13    RQ            NaN               NaN
# 68  2019-08-20    RQ            NaN               NaN
# 69  2019-08-17    RQ            NaN               NaN
#
# [70 rows x 21 columns]

# %% [markdown]
# Save FIRST luminosities and luminosity errors first

# %%
z = df[["z"]].values.flatten()
S1p4_first = df[["S1p4_FIRST"]].values.flatten()
S1p4err = df[["S1p4_err"]].values.flatten()
S6_firstup_err = np.zeros(len(S1p4err))

# %%
L6_first = radluminosity(6., 1.4, S1p4_first, -0.7, z)
L6_firstup = radluminosity(6., 1.4, S1p4_first, 0.0, z)

#for errors, consider detections separately; errors change logarithmically
fracerr = S1p4err/S1p4_first #turn fractional uncertainty into a variable
L6_first_uplim = np.log10(1+fracerr)
L6_first_lolim = abs(np.log10(1-fracerr))

#Now do fluxes
S6_first = LtoS(6., 6., L6_first, -0.7, z)
S6_first_err = S6_first*fracerr
S6_firstup = LtoS(6., 6., L6_firstup, 0.0, z)    
S6_firstup_err = S6_firstup*fracerr

# %%
#Save new values to table
df["L6_FIRST"] = L6_first
df["L6_FIRST_alpha0"] = L6_firstup
df["L6_FIRST_uplim"] = L6_first_uplim
df["L6_FIRST_lolim"] = L6_first_lolim
df["S6_FIRST"] = S6_first
df["S6_FIRST_err"] = S6_first_err
df["S6_FIRST_alpha0"] = S6_firstup
df["S6_FIRST_alpha0_err"] = S6_firstup_err
df
# Out:
#                   Name      z  S1p4_FIRST  S1p4_err   L6_FIRST  \
# 0   075403.60+481428.0  0.276        7910       160  23.800933
# 1   083658.90+442602.2  0.254        9150       120  23.784059
# 2   091702.11+212337.5  0.202        4190       130  23.225996
# 3   094215.12+090015.8  0.213        1690       130  22.882062
# 4   094603.94+013923.6  0.220        7330       150  23.550088
# ..                 ...    ...         ...       ...        ...
# 65  145824.46+363119.5  0.246         495         0  22.486485
# 66  084313.41+535718.8  0.218         516       150  22.388927
# 67  123532.83+410445.1  0.212         510         0  22.357267
# 68  161723.67+085414.7  0.206         450         0  22.275612
# 69  142522.37+080327.1  0.230         366         0  22.290917
#
#     L6_FIRST_alpha0  DATE_FIRST  S3_VLASS  S3_quaderr  L6_VLASS  ...  \
# 0         24.169254  1997-04-10    4070.0       820.0     23.74  ...
# 1         24.157667  1997-02-28    3940.0       805.0     23.65  ...
# 2         23.612479  1998-09-15    4190.0       850.0     23.46  ...
# 3         23.265776  2000-01-15    1300.0       279.0     23.00  ...
# 4         23.932053  1998-07-24    3810.0       773.0     23.50  ...
# ..              ...         ...       ...         ...       ...  ...
# 65        22.862038  1994-07-17       NaN         NaN     22.67  ...
# 66        22.771390  1997-05-07       NaN         NaN     22.45  ...
# 67        22.741231  1994-09-02       NaN         NaN     22.50  ...
# 68        22.661085  2000-01-15       NaN         NaN     22.59  ...
# 69        22.670400  2000-01-15       NaN         NaN     22.04  ...
#
#      DATE_VLAA CLASS  S3_VLASS_final  S3_quaderr_final L6_FIRST_uplim  \
# 0          NaN    RI          4395.6        952.860785       0.008697
# 1          NaN    RI          4255.2        933.669863       0.005659
# 2          NaN    RI          4525.2        986.802708       0.013270
# 3          NaN    RI          1495.0        342.416242       0.032185
# 4          NaN    RI          4381.5        955.560764       0.008798
# ..         ...   ...             ...               ...            ...
# 65  2019-09-20    RQ             NaN               NaN       0.000000
# 66  2019-08-13    RQ             NaN               NaN       0.110825
# 67  2019-08-13    RQ             NaN               NaN       0.000000
# 68  2019-08-20    RQ             NaN               NaN       0.000000
# 69  2019-08-17    RQ             NaN               NaN       0.000000
#
#     L6_FIRST_lolim     S6_FIRST S6_FIRST_err S6_FIRST_alpha0  \
# 0         0.008875  2856.013350    57.770182          7910.0
# 1         0.005733  3303.732257    43.327636          9150.0
# 2         0.013688  1512.856629    46.938273          4190.0
# 3         0.034762   610.197543    46.938273          1690.0
# 4         0.008980  2646.596442    54.159545          7330.0
# ..             ...          ...          ...             ...
# 65        0.000000   178.726499     0.000000           495.0
# 66        0.149169   186.308835    54.159545           516.0
# 67        0.000000   184.142454     0.000000           510.0
# 68        0.000000   162.478636     0.000000           450.0
# 69        0.000000   132.149290     0.000000           366.0
#
#     S6_FIRST_alpha0_err
# 0                 160.0
# 1                 120.0
# 2                 130.0
# 3                 130.0
# 4                 150.0
# ..                  ...
# 65                  0.0
# 66                150.0
# 67                  0.0
# 68                  0.0
# 69                  0.0
#
# [70 rows x 27 columns]

# %% [markdown]
# Re-compute the 6 GHz Luminosities from 2011

# %%
L6_kell_p7 = radluminosity(6., 6., df[["S(6)_p"]].values.flatten(), -0.7, z)
L6_kell_0 = radluminosity(6., 6., df[["S(6)_p"]].values.flatten(), 0.0, z)

fracerr = df[["pmp"]].values.flatten()/df[["S(6)_p"]].values.flatten()
kell_uplim = np.log10(1+fracerr)
kell_lolim = abs(np.log10(1-fracerr))

df["L6_Kell"] = L6_kell_p7
df["L6_Kell_alpha0"] = L6_kell_0
df["L6_Kell_uplim"] = kell_uplim
df["L6_Kell_lolim"] = kell_lolim
df
# Out:
#                   Name      z  S1p4_FIRST  S1p4_err   L6_FIRST  \
# 0   075403.60+481428.0  0.276        7910       160  23.800933
# 1   083658.90+442602.2  0.254        9150       120  23.784059
# 2   091702.11+212337.5  0.202        4190       130  23.225996
# 3   094215.12+090015.8  0.213        1690       130  22.882062
# 4   094603.94+013923.6  0.220        7330       150  23.550088
# ..                 ...    ...         ...       ...        ...
# 65  145824.46+363119.5  0.246         495         0  22.486485
# 66  084313.41+535718.8  0.218         516       150  22.388927
# 67  123532.83+410445.1  0.212         510         0  22.357267
# 68  161723.67+085414.7  0.206         450         0  22.275612
# 69  142522.37+080327.1  0.230         366         0  22.290917
#
#     L6_FIRST_alpha0  DATE_FIRST  S3_VLASS  S3_quaderr  L6_VLASS  ...  \
# 0         24.169254  1997-04-10    4070.0       820.0     23.74  ...
# 1         24.157667  1997-02-28    3940.0       805.0     23.65  ...
# 2         23.612479  1998-09-15    4190.0       850.0     23.46  ...
# 3         23.265776  2000-01-15    1300.0       279.0     23.00  ...
# 4         23.932053  1998-07-24    3810.0       773.0     23.50  ...
# ..              ...         ...       ...         ...       ...  ...
# 65        22.862038  1994-07-17       NaN         NaN     22.67  ...
# 66        22.771390  1997-05-07       NaN         NaN     22.45  ...
# 67        22.741231  1994-09-02       NaN         NaN     22.50  ...
# 68        22.661085  2000-01-15       NaN         NaN     22.59  ...
# 69        22.670400  2000-01-15       NaN         NaN     22.04  ...
#
#     L6_FIRST_uplim L6_FIRST_lolim     S6_FIRST  S6_FIRST_err S6_FIRST_alpha0  \
# 0         0.008697       0.008875  2856.013350     57.770182          7910.0
# 1         0.005659       0.005733  3303.732257     43.327636          9150.0
# 2         0.013270       0.013688  1512.856629     46.938273          4190.0
# 3         0.032185       0.034762   610.197543     46.938273          1690.0
# 4         0.008798       0.008980  2646.596442     54.159545          7330.0
# ..             ...            ...          ...           ...             ...
# 65        0.000000       0.000000   178.726499      0.000000           495.0
# 66        0.110825       0.149169   186.308835     54.159545           516.0
# 67        0.000000       0.000000   184.142454      0.000000           510.0
# 68        0.000000       0.000000   162.478636      0.000000           450.0
# 69        0.000000       0.000000   132.149290      0.000000           366.0
#
#     S6_FIRST_alpha0_err    L6_Kell L6_Kell_alpha0 L6_Kell_uplim  L6_Kell_lolim
# 0                 160.0  23.765294      23.691198      0.013777       0.014228
# 1                 120.0  23.679359      23.610551      0.013019       0.013421
# 2                 130.0  23.726534      23.670601      0.012899       0.013294
# 3                 130.0  23.161798      23.103095      0.014120       0.014594
# 4                 150.0  23.520273      23.459822      0.013173       0.013585
# ..                  ...        ...            ...           ...            ...
# 65                  0.0  22.457012      22.390149      0.023782       0.025160
# 66                150.0  22.731477      22.671524      0.015298       0.015857
# 67                  0.0  22.516994      22.458543      0.025521       0.027115
# 68                  0.0  22.645740      22.588797      0.016989       0.017681
# 69                  0.0  22.309731      22.246798      0.019989       0.020953
#
# [70 rows x 31 columns]

# %% [markdown]
# Do the VLASS fluxes now

# %%
S3_vlass = df[["S3_VLASS_final"]].values.flatten()
S3err = df[["S3_quaderr_final"]].values.flatten()

vlass = ~isNAN(S3_vlass)

L6_vlass = np.zeros(len(S3err))
L6_vlass_uplim = np.zeros(len(S3err))
L6_vlass_lolim = np.zeros(len(S3err))

L6_vlassup = np.zeros(len(S3err)) #luminosity assuming alpha=0.0

S6_vlass = np.zeros(len(S3err))
S6_vlass_err = np.zeros(len(S3err))
S6_vlassup = np.zeros(len(S3err))
S6_vlassup_err = np.zeros(len(S3err))

# %%
L6_vlass[vlass] = radluminosity(6., 3., S3_vlass[vlass], -0.7, z[vlass])
L6_vlassup[vlass] = radluminosity(6., 3., S3_vlass[vlass], 0.0, z[vlass])

fracerr = S3err[vlass]/S3_vlass[vlass]
L6_vlass_uplim[vlass] = np.log10(1+fracerr)
L6_vlass_lolim[vlass] = abs(np.log10(1-fracerr))

S6_vlass[vlass] = LtoS(6., 6., L6_vlass[vlass], -0.7, z[vlass])
S6_vlass_err[vlass] = S6_vlass[vlass]*fracerr
S6_vlassup[vlass] = LtoS(6., 6., L6_vlassup[vlass], 0.0, z[vlass])
S6_vlassup_err[vlass] = S6_vlassup[vlass]*fracerr

# %%
#Save new values to table
df["L6_VLASS"] = L6_vlass
df["L6_VLASS_alpha0"] = L6_vlassup
df["L6_VLASS_uplim"] = L6_vlass_uplim
df["L6_VLASS_lolim"] = L6_vlass_lolim
df["S6_VLASS"] = S6_vlass
df["S6_VLASS_err"] = S6_vlass_err
df["S6_VLASS_alpha0"] = S6_vlassup
df["S6_VLASS_alpha0_err"] = S6_vlassup_err
df
# Out:
#                   Name      z  S1p4_FIRST  S1p4_err   L6_FIRST  \
# 0   075403.60+481428.0  0.276        7910       160  23.800933
# 1   083658.90+442602.2  0.254        9150       120  23.784059
# 2   091702.11+212337.5  0.202        4190       130  23.225996
# 3   094215.12+090015.8  0.213        1690       130  22.882062
# 4   094603.94+013923.6  0.220        7330       150  23.550088
# ..                 ...    ...         ...       ...        ...
# 65  145824.46+363119.5  0.246         495         0  22.486485
# 66  084313.41+535718.8  0.218         516       150  22.388927
# 67  123532.83+410445.1  0.212         510         0  22.357267
# 68  161723.67+085414.7  0.206         450         0  22.275612
# 69  142522.37+080327.1  0.230         366         0  22.290917
#
#     L6_FIRST_alpha0  DATE_FIRST  S3_VLASS  S3_quaderr   L6_VLASS  ...  \
# 0         24.169254  1997-04-10    4070.0       820.0  23.777470  ...
# 1         24.157667  1997-02-28    3940.0       805.0  23.683253  ...
# 2         23.612479  1998-09-15    4190.0       850.0  23.491115  ...
# 3         23.265776  2000-01-15    1300.0       279.0  23.060512  ...
# 4         23.932053  1998-07-24    3810.0       773.0  23.558302  ...
# ..              ...         ...       ...         ...        ...  ...
# 65        22.862038  1994-07-17       NaN         NaN   0.000000  ...
# 66        22.771390  1997-05-07       NaN         NaN   0.000000  ...
# 67        22.741231  1994-09-02       NaN         NaN   0.000000  ...
# 68        22.661085  2000-01-15       NaN         NaN   0.000000  ...
# 69        22.670400  2000-01-15       NaN         NaN   0.000000  ...
#
#       L6_Kell L6_Kell_alpha0  L6_Kell_uplim  L6_Kell_lolim L6_VLASS_uplim  \
# 0   23.765294      23.691198       0.013777       0.014228       0.085211
# 1   23.679359      23.610551       0.013019       0.013421       0.086153
# 2   23.726534      23.670601       0.012899       0.013294       0.085672
# 3   23.161798      23.103095       0.014120       0.014594       0.089566
# 4   23.520273      23.459822       0.013173       0.013585       0.085679
# ..        ...            ...            ...            ...            ...
# 65  22.457012      22.390149       0.023782       0.025160       0.000000
# 66  22.731477      22.671524       0.015298       0.015857       0.000000
# 67  22.516994      22.458543       0.025521       0.027115       0.000000
# 68  22.645740      22.588797       0.016989       0.017681       0.000000
# 69  22.309731      22.246798       0.019989       0.020953       0.000000
#
#     L6_VLASS_lolim     S6_VLASS S6_VLASS_err S6_VLASS_alpha0  \
# 0         0.106114  2705.809192   586.554616          4395.6
# 1         0.107582  2619.382854   574.741218          4255.2
# 2         0.106831  2785.587350   607.448320          4525.2
# 3         0.112969   920.280449   210.781921          1495.0
# 4         0.106843  2697.129624   588.216648          4381.5
# ..             ...          ...          ...             ...
# 65        0.000000     0.000000     0.000000             0.0
# 66        0.000000     0.000000     0.000000             0.0
# 67        0.000000     0.000000     0.000000             0.0
# 68        0.000000     0.000000     0.000000             0.0
# 69        0.000000     0.000000     0.000000             0.0
#
#     S6_VLASS_alpha0_err
# 0            952.860785
# 1            933.669863
# 2            986.802708
# 3            342.416242
# 4            955.560764
# ..                  ...
# 65             0.000000
# 66             0.000000
# 67             0.000000
# 68             0.000000
# 69             0.000000
#
# [70 rows x 37 columns]

# %% [markdown]
# A configuration luminosities re-computed

# %%
L6_Aconfig_p7 = np.zeros(len(df[["S6_Aconfig"]].values.flatten()))
L6_Aconfig_0 = np.zeros(len(df[["S6_Aconfig"]].values.flatten()))

Aconfig_uplim = np.zeros(len(df[["S6_Aconfig"]].values.flatten()))
Aconfig_lolim = np.zeros(len(df[["S6_Aconfig"]].values.flatten()))

L6_Aconfig_p7[~vlass] = radluminosity(6., 6., df[["S6_Aconfig"]].values.flatten()[~vlass], -0.7, z[~vlass])
L6_Aconfig_0[~vlass] = radluminosity(6., 6., df[["S6_Aconfig"]].values.flatten()[~vlass], 0.0, z[~vlass])

fracerr = df[["S6_Aconfig_err"]].values.flatten()[~vlass]/df[["S6_Aconfig"]].values.flatten()[~vlass]
Aconfig_uplim[~vlass] = np.log10(1+fracerr)
Aconfig_lolim[~vlass] = np.log10(1-fracerr)

# %%
df["L6_Aconfig"] = L6_Aconfig_p7
df["L6_Aconfig_alpha0"] = L6_Aconfig_0
df["L6_Aconfig_uplim"] = Aconfig_uplim
df["L6_Aconfig_lolim"] = Aconfig_lolim
df
# Out:
#                   Name      z  S1p4_FIRST  S1p4_err   L6_FIRST  \
# 0   075403.60+481428.0  0.276        7910       160  23.800933
# 1   083658.90+442602.2  0.254        9150       120  23.784059
# 2   091702.11+212337.5  0.202        4190       130  23.225996
# 3   094215.12+090015.8  0.213        1690       130  22.882062
# 4   094603.94+013923.6  0.220        7330       150  23.550088
# ..                 ...    ...         ...       ...        ...
# 65  145824.46+363119.5  0.246         495         0  22.486485
# 66  084313.41+535718.8  0.218         516       150  22.388927
# 67  123532.83+410445.1  0.212         510         0  22.357267
# 68  161723.67+085414.7  0.206         450         0  22.275612
# 69  142522.37+080327.1  0.230         366         0  22.290917
#
#     L6_FIRST_alpha0  DATE_FIRST  S3_VLASS  S3_quaderr   L6_VLASS  ...  \
# 0         24.169254  1997-04-10    4070.0       820.0  23.777470  ...
# 1         24.157667  1997-02-28    3940.0       805.0  23.683253  ...
# 2         23.612479  1998-09-15    4190.0       850.0  23.491115  ...
# 3         23.265776  2000-01-15    1300.0       279.0  23.060512  ...
# 4         23.932053  1998-07-24    3810.0       773.0  23.558302  ...
# ..              ...         ...       ...         ...        ...  ...
# 65        22.862038  1994-07-17       NaN         NaN   0.000000  ...
# 66        22.771390  1997-05-07       NaN         NaN   0.000000  ...
# 67        22.741231  1994-09-02       NaN         NaN   0.000000  ...
# 68        22.661085  2000-01-15       NaN         NaN   0.000000  ...
# 69        22.670400  2000-01-15       NaN         NaN   0.000000  ...
#
#     L6_VLASS_uplim L6_VLASS_lolim     S6_VLASS  S6_VLASS_err S6_VLASS_alpha0  \
# 0         0.085211       0.106114  2705.809192    586.554616          4395.6
# 1         0.086153       0.107582  2619.382854    574.741218          4255.2
# 2         0.085672       0.106831  2785.587350    607.448320          4525.2
# 3         0.089566       0.112969   920.280449    210.781921          1495.0
# 4         0.085679       0.106843  2697.129624    588.216648          4381.5
# ..             ...            ...          ...           ...             ...
# 65        0.000000       0.000000     0.000000      0.000000             0.0
# 66        0.000000       0.000000     0.000000      0.000000             0.0
# 67        0.000000       0.000000     0.000000      0.000000             0.0
# 68        0.000000       0.000000     0.000000      0.000000             0.0
# 69        0.000000       0.000000     0.000000      0.000000             0.0
#
#     S6_VLASS_alpha0_err  L6_Aconfig L6_Aconfig_alpha0 L6_Aconfig_uplim  \
# 0            952.860785    0.000000          0.000000         0.000000
# 1            933.669863    0.000000          0.000000         0.000000
# 2            986.802708    0.000000          0.000000         0.000000
# 3            342.416242    0.000000          0.000000         0.000000
# 4            955.560764    0.000000          0.000000         0.000000
# ..                  ...         ...               ...              ...
# 65             0.000000   22.550266         22.483403         0.060607
# 66             0.000000   22.661519         22.601566         0.036958
# 67             0.000000   22.835623         22.777171         0.049582
# 68             0.000000   22.652190         22.595246         0.019936
# 69             0.000000   22.512275         22.449341         0.028645
#
#     L6_Aconfig_lolim
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4           0.000000
# ..               ...
# 65         -0.070458
# 66         -0.040398
# 67         -0.055981
# 68         -0.020895
# 69         -0.030669
#
# [70 rows x 41 columns]

# %%
df.to_csv("all_var_figs.csv", index=False)

# %% [markdown]
# Done 9/1/2020
